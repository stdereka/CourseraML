# %%
import numpy
numpy.__version__
# Out:
# '1.14.0'

# %%
import scipy
scipy.__version__
# Out:
# '1.0.0'

# %%
import pandas
pandas.__version__
# Out:
# u'0.22.0'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '2.1.1'
